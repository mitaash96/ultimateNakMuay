# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Send a GET request to the Wikipedia page
url = 'https://en.wikipedia.org/wiki/List_of_ONE_Championship_events#Events'
response = requests.get(url)

# Create a BeautifulSoup object with the HTML content
soup = BeautifulSoup(response.text, 'html.parser')

# Find the events table on the page
events_table = soup.find('table', class_='wikitable')

# %%
def get_events_df(table):
    headers = [_.text.strip() for _ in table.find_all('th')]
    
    rows = [
        [td.text.strip() for td in tr.find_all('td')]
        for tr in table.find_all('tr')[1:]
        ]
    
    df = pd.DataFrame(rows, columns=headers)

    return df

# %%
df = get_events_df(events_table)

# %%
df
# Out:
#        #                                              Event              Date  \
# 0    253          ONE Fight Night 13: Allazov vs. Grigorian    August 5, 2023
# 1    252                                 ONE Fight Night 12     July 15, 2023
# 2    251         ONE Friday Fights 22: Bhullar vs. Malykhin     June 23, 2023
# 3    250                               ONE Friday Fights 21     June 16, 2023
# 4    249           ONE Fight Night 11: Eersel vs. Menshikov     June 10, 2023
# ..   ...                                                ...               ...
# 260    5                          ONE FC: Pride of a Nation    31 August 2012
# 261    4                        ONE FC: Destiny of Warriors      23 June 2012
# 262    3                           ONE FC: War of the Lions     31 March 2012
# 263    2                           ONE FC: Battle of Heroes  11 February 2012
# 264    1  ONE Fighting Championship 1: Champion vs. Cham...  3 September 2011
#
#                         Venue                  Location Attendance
# 0     Lumpinee Boxing Stadium         Bangkok, Thailand
# 1                                                  None       None
# 2                                                  None       None
# 3                                                  None       None
# 4                                                  None       None
# ..                        ...                       ...        ...
# 260    Smart Araneta Coliseum  Quezon City, Philippines     12,523
# 261            Stadium Negara    Kuala Lumpur, Malaysia      6,153
# 262  Singapore Indoor Stadium        Kallang, Singapore      7,714
# 263         The BritAma Arena  North Jakarta, Indonesia      3,371
# 264  Singapore Indoor Stadium        Kallang, Singapore      6,789
#
# [265 rows x 6 columns]
