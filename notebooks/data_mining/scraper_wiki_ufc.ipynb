# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Send a GET request to the Wikipedia page
url = 'https://en.wikipedia.org/wiki/List_of_UFC_events'
response = requests.get(url)

# Create a BeautifulSoup object with the HTML content
soup = BeautifulSoup(response.text, 'html.parser')

# Find the events table on the page
past_events_table = soup.find('table', class_='wikitable', id="Past_events")
scheduled_events_table = soup.find('table', class_='wikitable', id="Scheduled_events")

# %%
def get_events_df(table):
    headers = [_.text.strip() for _ in table.find_all('th')]
    
    rows = [
        [td.text.strip() for td in tr.find_all('td')]
        for tr in table.find_all('tr')[1:]
        ]
    
    df = pd.DataFrame(rows, columns=headers)

    return df

# %%
past_events_df, scheduled_events_df = get_events_df(past_events_table), get_events_df(scheduled_events_table)

# %%
df = pd.concat([past_events_df, scheduled_events_df], ignore_index=True)

# %%
df
# Out:
#        #                                   Event          Date  \
# 0    648          UFC Fight Night: Dern vs. Hill  May 20, 2023
# 1    647     UFC on ABC: Rozenstruik vs. Almeida  May 13, 2023
# 2    646            UFC 288: Sterling vs. Cejudo   May 6, 2023
# 3    645             UFC on ESPN: Song vs. Simón  Apr 29, 2023
# 4    644  UFC Fight Night: Pavlovich vs. Blaydes  Apr 22, 2023
# ..   ...                                     ...           ...
# 666  NaN   UFC on ESPN: Strickland vs. Magomedov   Jul 1, 2023
# 667  NaN          UFC on ABC: Emmett vs. Topuria  Jun 24, 2023
# 668  NaN      UFC on ESPN: Vettori vs. Cannonier  Jun 17, 2023
# 669  NaN               UFC 289: Nunes vs. Aldana  Jun 10, 2023
# 670  NaN     UFC on ESPN: Kara-France vs. Albazi   Jun 3, 2023
#
#                               Venue                             Location  \
# 0                          UFC Apex              Las Vegas, Nevada, U.S.
# ...

# %%
r"C:\Development\ultimateNakMuay\data\raw\ufcstats.json".split('.')[-1]
# Out:
# 'json'
